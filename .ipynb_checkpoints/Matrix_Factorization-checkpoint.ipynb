# %%
import numpy as np

def grad_U(Ui, Yij, Vj, reg, eta):
    """
    Takes as input Ui (the ith row of U), a training point Yij, the column
    vector Vj (jth column of V^T), reg (the regularization parameter lambda),
    and eta (the learning rate).

    Returns the gradient of the regularized loss function with
    respect to Ui multiplied by eta.
    """
    return eta * (reg * Ui - Yij * Vj + Ui.dot(Vj) * Vj)

def grad_V(Vj, Yij, Ui, reg, eta):
    """
    Takes as input the column vector Vj (jth column of V^T), a training point Yij,
    Ui (the ith row of U), reg (the regularization parameter lambda),
    and eta (the learning rate).

    Returns the gradient of the regularized loss function with
    respect to Vj multiplied by eta.
    """
    return eta * (reg * Vj - Yij * Ui + Ui.dot(Vj) * Ui)

def grad_bias(Vj, Yij, Ui, eta, ai, bj):
    """
    Takes as input the column vector Vj (jth column of V^T), a training point Yij,
    Ui (the ith row of U), reg (the regularization parameter lambda),
    and eta (the learning rate), and bias entries ai, bj.

    Returns the gradient of the regularized loss function with
    respect to bias multiplied by learning rate.
    """
    return -eta * (Yij - (Ui.dot(Vj) + ai + bj))

def get_err(U, V, Y, reg=0.0):
    """
    Takes as input a matrix Y of triples (i, j, Y_ij) where i is the index of a user,
    j is the index of a movie, and Y_ij is user i's rating of movie j and
    user/movie matrices U and V.

    Returns the mean regularized squared-error of predictions made by
    estimating Y_{ij} as the dot product of the ith row of U and the jth column of V^T.
    """
    sum_u = np.linalg.norm(U, ord = 'fro') ** 2
    sum_v = np.linalg.norm(V, ord = 'fro') ** 2
    sum_err = 0
    for i, j, rating in Y:
        i -= 1
        j -= 1
        sum_err += (rating - U[i, :].T.dot(V[j, :])) ** 2
    return reg / 2 * (sum_u + sum_v) + sum_err / 2

def get_err_bias(U, V, Y, a, b, reg = 0.0):
    sum_u = np.linalg.norm(U, ord = 'fro') ** 2
    sum_v = np.linalg.norm(V, ord = 'fro') ** 2
    sum_err = 0
    for i, j, rating in Y:
        i -= 1
        j -= 1
        if i >= U.shape[0] or j >= V.shape[0]:
            continue
        sum_err += (rating - U[i, :].T.dot(V[j, :]) - a[i] - b[j]) ** 2
    return reg / 2 * (sum_u + sum_v) + sum_err / 2

def get_err_shelf(shelf, U, V, Y):
    err = 0
    sum_u = np.linalg.norm(U, ord = 'fro') ** 2
    sum_v = np.linalg.norm(V, ord = 'fro') ** 2
    for i, j, rating in Y:
        err += (rating - shelf.predict(i, j, r_ui = rating).est) ** 2
    return reg / 2 * (sum_u + sum_v) + err / 2    

def train_model(M, N, K, eta, reg, Y, eps=0.0001, max_epochs=300, bias = False):
    """
    Given a training data matrix Y containing rows (i, j, Y_ij)
    where Y_ij is user i's rating on movie j, learns an
    M x K matrix U and N x K matrix V such that rating Y_ij is approximated
    by (UV^T)_ij.

    Uses a learning rate of <eta> and regularization of <reg>. Stops after
    <max_epochs> epochs, or once the magnitude of the decrease in regularized
    MSE between epochs is smaller than a fraction <eps> of the decrease in
    MSE after the first epoch.

    Returns a tuple (U, V, err) consisting of U, V, and the unregularized MSE
    of the model.
    """
    U = np.random.uniform(-0.5, 0.5, size = (M, K))
    V = np.random.uniform(-0.5, 0.5, size = (N, K))
    if bias:
        a = np.random.uniform(-0.5, 0.5, size = (M, ))
        b = np.random.uniform(-0.5, 0.5, size = (N, ))
    first_reduction = 0
    for k in range(max_epochs):
        if bias:
            curr_err = get_err_bias(U, V, Y, a, b, reg)
        else:
            curr_err = get_err(U, V, Y, reg)
        for i, j, rating in np.random.permutation(Y):
            i -= 1
            j -= 1
            Ui = np.copy(U[i, :])
            Vj = np.copy(V[j, :])
            U[i, :] -= grad_U(Ui, rating, Vj, reg, eta)
            V[j, :] -= grad_V(Vj, rating, Ui, reg, eta)
            if bias:
                ai = a[i]
                bj = b[j]
                change = grad_bias(Vj, rating, Ui, eta, ai, bj)
                a[i] -= change
                b[j] -= change
        if bias:
            next_err = get_err_bias(U, V, Y, a, b, reg)
        else:
            next_err = get_err(U, V, Y, reg)
        if k == 0:
            first_reduction = curr_err - next_err
        else:
            if (curr_err - next_err) / first_reduction <= eps:
                break
    if bias:
        return (U, V, next_err, a, b)
    else:
        return (U, V, next_err)

# %%
Y_train = np.loadtxt('data/train.txt').astype(int)
Y_test = np.loadtxt('data/test.txt').astype(int)

M = max(max(Y_train[:,0]), max(Y_test[:,0])).astype(int) # users
N = max(max(Y_train[:,1]), max(Y_test[:,1])).astype(int) # movies
print("Factorizing with ", M, " users, ", N, " movies.")
K = 20

reg = 0.0
eta = 0.03 # learning rate

U1,V1, err = train_model(M, N, K, eta, reg, Y_train)
E_in_no_bias = err
E_out_no_bias = get_err(U1, V1, Y_test)

# %%
print(E_in_no_bias)
print(E_out_no_bias)

# %%
U2, V2, err, a, b = train_model(M, N, K, eta, reg, Y_train, bias = True)
E_in_bias = err
E_out_bias = get_err_bias(U2, V2, Y_test, a, b)

# %%
print(E_in_bias)
print(E_out_bias)

# %%
from surprise import SVD, Reader, Dataset
import pandas as pd
shelf = SVD(n_factors = K, n_epochs = 300, lr_all = eta, reg_all = 0)
df = pd.DataFrame({'userID': Y_train[:, 0], 'movieID': Y_train[:, 1], 'rating': Y_train[:, 2]})
reader = Reader(rating_scale = (1, 5))
data = Dataset.load_from_df(df[['userID', 'movieID', 'rating']], reader)
trainset = data.build_full_trainset()
shelf.fit(trainset)
E_in_shelf = get_err_shelf(shelf, shelf.pu, shelf.qi, Y_train)
E_out_shelf = get_err_shelf(shelf, shelf.pu, shelf.qi, Y_test)
U3 = shelf.pu
V3 = shelf.qi

# %%
print(E_in_shelf)
print(E_out_shelf)

# %% [markdown]
# # 2D visualization

# %%
V1_ = np.copy(V1)
U1_ = np.copy(U1)
V2_ = np.copy(V2)
U2_ = np.copy(U2)
V3_ = np.copy(V3)
U3_ = np.copy(U3)

# %%
#mean centering V
means = V1_.mean(axis = 0)
V1_ -= means

#shift U by same amount
U1_ -= means

#mean centering V
means = V2_.mean(axis = 0)
V2_ -= means

#shift U by same amount
U2_ -= means

#mean centering V
means = V3_.mean(axis = 0)
V3_ -= means

#shift U by same amount
U3_ -= means

# %%
# 1 is without bias, 2 is with bias, 3 is surprise
A1, Sig1, B1 = np.linalg.svd(V1_.T, full_matrices=False)
A2, Sig2, B2 = np.linalg.svd(V2_.T, full_matrices=False)
A3, Sig3, B3 = np.linalg.svd(V3_.T, full_matrices=False)

# %%
V1_proj = A1[:,:2].T.dot(V1_.T)
U1_proj = A1[:,:2].T.dot(U1_.T)
V2_proj = A2[:,:2].T.dot(V2_.T)
U2_proj = A2[:,:2].T.dot(U2_.T)
V3_proj = A3[:,:2].T.dot(V3_.T)
U3_proj = A3[:,:2].T.dot(U3_.T)

# %%
# #rescaling so that each row of U_proj and V_proj has unit variance
# from sklearn import preprocessing

# V_proj = preprocessing.scale(V_proj)
# U_proj = preprocessing.scale(U_proj)

#Doesn't work!!

# %%
import matplotlib.pyplot as plt
import random
import csv

with open("data/movies.txt", encoding="latin_1") as f:
    reader = csv.reader(f, delimiter="\t")
    
    # Put the contents in a matrix
    movies = np.array(list(reader))

# %%
import matplotlib.pyplot as plt
import random

mov_i = np.random.choice(range(0, 1682), 10)
names = movies[:,1][mov_i]
plt.figure(figsize=(9,9))
for idx, i in enumerate(mov_i):
    x = V1_proj[0,:][i]
    y = V1_proj[1,:][i]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[idx], fontsize=9)
plt.title("Ten Random Movies Using SGD Without Bias")
plt.show()

plt.figure(figsize=(9,9))
for idx, i in enumerate(mov_i):
    x = V2_proj[0,:][i]
    y = V2_proj[1,:][i]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[idx], fontsize=9)
plt.title("Ten Random Movies Using SGD With Bias")
plt.show()

plt.figure(figsize=(9,9))
for idx, i in enumerate(mov_i):
    x = V3_proj[0,:][i]
    y = V3_proj[1,:][i]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[idx], fontsize=9)
plt.title("Ten Random Movies Using Surprise Package")
plt.show()

# %%
from collections import Counter
data = np.loadtxt("data/data.txt")
most_popular = Counter(data[:, 1]).most_common(10)
names = {}
for index, _ in most_popular:
    names[index] = movies[int(index) - 1, 1]

plt.figure(figsize=(9,9))
for index, _ in most_popular:
    x = V1_proj[0,:][int(index) - 1]
    y = V1_proj[1,:][int(index) - 1]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[index], fontsize=9)
    
plt.title("Ten Most Popular Movies Using SGD Without Bias")
plt.show()

plt.figure(figsize=(9,9))
for index, _ in most_popular:
    x = V2_proj[0,:][int(index) - 1]
    y = V2_proj[1,:][int(index) - 1]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[index], fontsize=9)
plt.title("Ten Most Popular Movies Using SGD With Bias")
plt.show()

plt.figure(figsize=(9,9))
for index, _ in most_popular:
    x = V3_proj[0,:][int(index) - 1]
    y = V3_proj[1,:][int(index) - 1]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[index], fontsize=9)
plt.title("Ten Most Popular Movies Using Surprise")
plt.show()

# %%
count_ratings = Counter(data[:, 1])
rating_sum = {}
for u, m, rating in data:
    if rating_sum.get(m, -1) == -1:
        rating_sum[m] = rating
    else:
        rating_sum[m] += rating
for key in rating_sum:
    rating_sum[key] = rating_sum[key] / count_ratings[key]

import operator
# Get top 10 movies with highest average rating
sorted_ratings = sorted(rating_sum.items(), key=operator.itemgetter(1))[-10:]
names = {}
for index, _ in sorted_ratings:
    names[index] = movies[int(index) - 1, 1]

plt.figure(figsize=(9,9))
for index, _ in sorted_ratings:
    x = V1_proj[0,:][int(index) - 1]
    y = V1_proj[1,:][int(index) - 1]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[index], fontsize=9)
    
plt.title("Ten Highest Rated Movies Using SGD Without Bias")
plt.show()

plt.figure(figsize=(9,9))
for index, _ in sorted_ratings:
    x = V2_proj[0,:][int(index) - 1]
    y = V2_proj[1,:][int(index) - 1]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[index], fontsize=9)
plt.title("Ten Highest Rated Movies Using SGD With Bias")
plt.show()

plt.figure(figsize=(9,9))
for index, _ in sorted_ratings:
    x = V3_proj[0,:][int(index) - 1]
    y = V3_proj[1,:][int(index) - 1]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[index], fontsize=9)
plt.title("Ten Highest Rated Movies Using Surprise")
plt.show()

# %%
# Find Action Movies 4th column
IDs = []
for i, line in enumerate(movies):
    if int(line[3]):
        IDs.append(i)
mov_i = np.random.choice(IDs, 10)


names = movies[:,1][mov_i]

plt.figure(figsize=(9,9))
for idx, i in enumerate(mov_i):
    x = V1_proj[0,:][i]
    y = V1_proj[1,:][i]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[idx], fontsize=9)
plt.title("Ten Action MOvies Using SGD Without Bias")
plt.show()

plt.figure(figsize=(9,9))
for idx, i in enumerate(mov_i):
    x = V2_proj[0,:][i]
    y = V2_proj[1,:][i]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[idx], fontsize=9)
plt.title("Ten Action MOvies Using SGD With Bias")
plt.show()

plt.figure(figsize=(9,9))
for idx, i in enumerate(mov_i):
    x = V3_proj[0,:][i]
    y = V3_proj[1,:][i]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[idx], fontsize=9)
plt.title("Ten Action MOvies Using Surprise")
plt.show()

# %%
# Find Adventure Movies 5th column
IDs = []
for i, line in enumerate(movies):
    if int(line[4]):
        IDs.append(i)
mov_i = np.random.choice(IDs, 10)


names = movies[:,1][mov_i]

plt.figure(figsize=(9,9))
for idx, i in enumerate(mov_i):
    x = V1_proj[0,:][i]
    y = V1_proj[1,:][i]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[idx], fontsize=9)
plt.title("Ten Adventure MOvies Using SGD Without Bias")
plt.show()

plt.figure(figsize=(9,9))
for idx, i in enumerate(mov_i):
    x = V2_proj[0,:][i]
    y = V2_proj[1,:][i]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[idx], fontsize=9)
plt.title("Ten Adventure MOvies Using SGD With Bias")
plt.show()

plt.figure(figsize=(9,9))
for idx, i in enumerate(mov_i):
    x = V3_proj[0,:][i]
    y = V3_proj[1,:][i]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[idx], fontsize=9)
plt.title("Ten Adventure MOvies Using Surprise")
plt.show()

# %%
# Find Animated Movies 6th column
IDs = []
for i, line in enumerate(movies):
    if int(line[5]):
        IDs.append(i)
mov_i = np.random.choice(IDs, 10)


names = movies[:,1][mov_i]

plt.figure(figsize=(9,9))
for idx, i in enumerate(mov_i):
    x = V1_proj[0,:][i]
    y = V1_proj[1,:][i]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[idx], fontsize=9)
plt.title("Ten Animated Movies Using SGD Without Bias")
plt.show()

plt.figure(figsize=(9,9))
for idx, i in enumerate(mov_i):
    x = V2_proj[0,:][i]
    y = V2_proj[1,:][i]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[idx], fontsize=9)
plt.title("Ten Animated Movies Using SGD With Bias")
plt.show()

plt.figure(figsize=(9,9))
for idx, i in enumerate(mov_i):
    x = V3_proj[0,:][i]
    y = V3_proj[1,:][i]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[idx], fontsize=9)
plt.title("Ten Animated Movies Using Surprise")
plt.show()

# %%
mov_i = [438, 439, 0, 49, 226, 227, 228, 229, 184, 199, 487, 68, 87, 819]


names = movies[:,1][mov_i]

plt.figure(figsize=(9,9))
for idx, i in enumerate(mov_i):
    x = V1_proj[0,:][i]
    y = V1_proj[1,:][i]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[idx], fontsize=9)
plt.title("Ten Chosen Movies Using SGD Without Bias")
plt.show()

plt.figure(figsize=(9,9))
for idx, i in enumerate(mov_i):
    x = V2_proj[0,:][i]
    y = V2_proj[1,:][i]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[idx], fontsize=9)
plt.title("Ten Chosen Movies Using SGD With Bias")
plt.show()

plt.figure(figsize=(9,9))
for idx, i in enumerate(mov_i):
    x = V3_proj[0,:][i]
    y = V3_proj[1,:][i]
    plt.scatter(x, y, marker='x', color='red')
    plt.text(x, y, names[idx], fontsize=9)
plt.title("Ten Chosen Movies Using Surprise")
plt.show()

# %%
genres = np.array(['Unknown', 'Action', 'Adventure', 'Animation', 'Children’s', 'Comedy', 'Crime', 'Documentary',\
        'Drama', 'Fantasy', 'Film-Noir', 'Horror', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western'])
num = len(genres)
lst = []
for i, row in enumerate(movies):
    genre = genres[np.nonzero(list(map(int, movies[i][2:])))]
    print(i, row[1], genre)
# Out:
# 0 Toy Story (1995) ['Animation' 'Children’s' 'Comedy']
# 1 GoldenEye (1995) ['Action' 'Adventure' 'Thriller']
# 2 Four Rooms (1995) ['Thriller']
# 3 Get Shorty (1995) ['Action' 'Comedy' 'Drama']
# 4 Copycat (1995) ['Crime' 'Drama' 'Thriller']
# 5 Shanghai Triad (Yao a yao yao dao waipo qiao) (1995) ['Drama']
# 6 Twelve Monkeys (1995) ['Drama' 'Sci-Fi']
# 60 Three Colors: White (1994) ['Drama']
# 61 Stargate (1994) ['Action' 'Adventure' 'Sci-Fi']
# 62 Santa Clause, The (1994) ['Children’s' 'Comedy']
# 63 Shawshank Redemption, The (1994) ['Drama']
# 64 What's Eating Gilbert Grape (1993) ['Comedy' 'Drama']
# 65 While You Were Sleeping (1995) ['Comedy' 'Romance']
# 66 Ace Ventura: Pet Detective (1994) ['Comedy']
# 67 Crow, The (1994) ['Action' 'Romance' 'Thriller']
# 68 Forrest Gump (1994) ['Comedy' 'Romance' 'War']
# 69 Four Weddings and a Funeral (1994) ['Comedy' 'Romance']
# 70 Lion King, The (1994) ['Animation' 'Children’s' 'Musical']
# 71 Mask, The (1994) ['Comedy' 'Crime' 'Fantasy']
# 72 Maverick (1994) ['Action' 'Comedy' 'Western']
# 73 Faster Pussycat! Kill! Kill! (1965) ['Action' 'Comedy' 'Drama']
# 74 Brother Minister: The Assassination of Malcolm X (1994) ['Documentary']
# 75 Carlito's Way (1993) ['Crime' 'Drama']
# 76 Firm, The (1993) ['Drama' 'Thriller']
# 77 Free Willy (1993) ['Adventure' 'Children’s' 'Drama']
# 78 Fugitive, The (1993) ['Action' 'Thriller']
# 79 Hot Shots! Part Deux (1993) ['Action' 'Comedy' 'War']
# 80 Hudsucker Proxy, The (1994) ['Comedy' 'Romance']
# 81 Jurassic Park (1993) ['Action' 'Adventure' 'Sci-Fi']
# 82 Much Ado About Nothing (1993) ['Comedy' 'Romance']
# 83 Robert A. Heinlein's The Puppet Masters (1994) ['Horror' 'Sci-Fi']
# 84 Ref, The (1994) ['Comedy']
# 85 Remains of the Day, The (1993) ['Drama']
# 86 Searching for Bobby Fischer (1993) ['Drama']
# 87 Sleepless in Seattle (1993) ['Comedy' 'Romance']
# 88 Blade Runner (1982) ['Film-Noir' 'Sci-Fi']
# 89 So I Married an Axe Murderer (1993) ['Comedy' 'Romance' 'Thriller']
# 90 Nightmare Before Christmas, The (1993) ['Children’s' 'Comedy' 'Musical']
# 91 True Romance (1993) ['Action' 'Crime' 'Romance']
# 92 Welcome to the Dollhouse (1995) ['Comedy' 'Drama']
# 93 Home Alone (1990) ['Children’s' 'Comedy']
# 94 Aladdin (1992) ['Animation' 'Children’s' 'Comedy' 'Musical']
# 95 Terminator 2: Judgment Day (1991) ['Action' 'Sci-Fi' 'Thriller']
# 96 Dances with Wolves (1990) ['Adventure' 'Drama' 'Western']
# 97 Silence of the Lambs, The (1991) ['Drama' 'Thriller']
# 98 Snow White and the Seven Dwarfs (1937) ['Animation' 'Children’s' 'Musical']
# 99 Fargo (1996) ['Crime' 'Drama' 'Thriller']
# 100 Heavy Metal (1981) ['Action' 'Adventure' 'Animation' 'Horror' 'Sci-Fi']
# 101 Aristocats, The (1970) ['Animation' 'Children’s']
# 102 All Dogs Go to Heaven 2 (1996) ['Animation' 'Children’s' 'Musical']
# 103 Theodore Rex (1995) ['Comedy']
# 104 Sgt. Bilko (1996) ['Comedy']
# 105 Diabolique (1996) ['Drama' 'Thriller']
# 106 Moll Flanders (1996) ['Drama']
# 155 Reservoir Dogs (1992) ['Crime' 'Thriller']
# 156 Platoon (1986) ['Drama' 'War']
# 157 Weekend at Bernie's (1989) ['Comedy']
# 158 Basic Instinct (1992) ['Mystery' 'Thriller']
# 159 Glengarry Glen Ross (1992) ['Drama']
# 160 Top Gun (1986) ['Action' 'Romance']
# 161 On Golden Pond (1981) ['Drama']
# 162 Return of the Pink Panther, The (1974) ['Comedy']
# 163 Abyss, The (1989) ['Action' 'Adventure' 'Sci-Fi' 'Thriller']
# 164 Jean de Florette (1986) ['Drama']
# 165 Manon of the Spring (Manon des sources) (1986) ['Drama']
# 166 Private Benjamin (1980) ['Comedy']
# 167 Monty Python and the Holy Grail (1974) ['Comedy']
# 168 Wrong Trousers, The (1993) ['Animation' 'Comedy']
# 169 Cinema Paradiso (1988) ['Comedy' 'Drama' 'Romance']
# 170 Delicatessen (1991) ['Comedy' 'Sci-Fi']
# 171 Empire Strikes Back, The (1980) ['Action' 'Adventure' 'Drama' 'Romance' 'Sci-Fi' 'War']
# 172 Princess Bride, The (1987) ['Action' 'Adventure' 'Comedy' 'Romance']
# 173 Raiders of the Lost Ark (1981) ['Action' 'Adventure']
# 174 Brazil (1985) ['Sci-Fi']
# 175 Aliens (1986) ['Action' 'Sci-Fi' 'Thriller' 'War']
# 176 Good, The Bad and The Ugly, The (1966) ['Action' 'Western']
# 177 12 Angry Men (1957) ['Drama']
# 178 Clockwork Orange, A (1971) ['Sci-Fi']
# 179 Apocalypse Now (1979) ['Drama' 'War']
# 180 Return of the Jedi (1983) ['Action' 'Adventure' 'Romance' 'Sci-Fi' 'War']
# 181 GoodFellas (1990) ['Crime' 'Drama']
# 182 Alien (1979) ['Action' 'Horror' 'Sci-Fi' 'Thriller']
# 183 Army of Darkness (1993) ['Action' 'Adventure' 'Comedy' 'Horror' 'Sci-Fi']
# 184 Psycho (1960) ['Horror' 'Romance' 'Thriller']
# 185 Blues Brothers, The (1980) ['Action' 'Comedy' 'Musical']
# 186 Godfather: Part II, The (1974) ['Action' 'Crime' 'Drama']
# 187 Full Metal Jacket (1987) ['Action' 'Drama' 'War']
# 188 Grand Day Out, A (1992) ['Animation' 'Comedy']
# 189 Henry V (1989) ['Drama' 'War']
# 190 Amadeus (1984) ['Drama' 'Mystery']
# 191 Raging Bull (1980) ['Drama']
# 192 Right Stuff, The (1983) ['Drama']
# 193 Sting, The (1973) ['Comedy' 'Crime']
# 194 Terminator, The (1984) ['Action' 'Sci-Fi' 'Thriller']
# 195 Dead Poets Society (1989) ['Drama']
# 196 Graduate, The (1967) ['Drama' 'Romance']
# 197 Nikita (La Femme Nikita) (1990) ['Thriller']
# 198 Bridge on the River Kwai, The (1957) ['Drama' 'War']
# 199 Shining, The (1980) ['Horror']
# 200 Evil Dead II (1987) ['Action' 'Adventure' 'Comedy' 'Horror']
# 201 Groundhog Day (1993) ['Comedy' 'Romance']
# 202 Unforgiven (1992) ['Western']
# 203 Back to the Future (1985) ['Comedy' 'Sci-Fi']
# 204 Patton (1970) ['Drama' 'War']
# 205 Akira (1988) ['Adventure' 'Animation' 'Sci-Fi' 'Thriller']
# 206 Cyrano de Bergerac (1990) ['Action' 'Drama' 'Romance']
# 207 Young Frankenstein (1974) ['Comedy' 'Horror']
# 208 This Is Spinal Tap (1984) ['Comedy' 'Drama' 'Musical']
# 209 Indiana Jones and the Last Crusade (1989) ['Action' 'Adventure']
# 210 M*A*S*H (1970) ['Comedy' 'War']
# 211 Unbearable Lightness of Being, The (1988) ['Drama']
# 212 Room with a View, A (1986) ['Drama' 'Romance']
# 213 Pink Floyd - The Wall (1982) ['Drama' 'Musical' 'War']
# 214 Field of Dreams (1989) ['Drama']
# 215 When Harry Met Sally... (1989) ['Comedy' 'Romance']
# 216 Bram Stoker's Dracula (1992) ['Horror' 'Romance']
# 217 Cape Fear (1991) ['Thriller']
# 218 Nightmare on Elm Street, A (1984) ['Horror']
# 219 Mirror Has Two Faces, The (1996) ['Comedy' 'Romance']
# 220 Breaking the Waves (1996) ['Drama']
# 221 Star Trek: First Contact (1996) ['Action' 'Adventure' 'Sci-Fi']
# 222 Sling Blade (1996) ['Drama' 'Thriller']
# 223 Ridicule (1996) ['Drama']
# 224 101 Dalmatians (1996) ['Children’s' 'Comedy']
# 225 Die Hard 2 (1990) ['Action' 'Thriller']
# 226 Star Trek VI: The Undiscovered Country (1991) ['Action' 'Adventure' 'Sci-Fi']
# 227 Star Trek: The Wrath of Khan (1982) ['Action' 'Adventure' 'Sci-Fi']
# 228 Star Trek III: The Search for Spock (1984) ['Action' 'Adventure' 'Sci-Fi']
# 229 Star Trek IV: The Voyage Home (1986) ['Action' 'Adventure' 'Sci-Fi']
# 230 Batman Returns (1992) ['Action' 'Adventure' 'Comedy' 'Crime']
# 231 Young Guns (1988) ['Action' 'Comedy' 'Western']
# 232 Under Siege (1992) ['Action']
# 233 Jaws (1975) ['Action' 'Horror']
# 234 Mars Attacks! (1996) ['Action' 'Comedy' 'Sci-Fi' 'War']
# 235 Citizen Ruth (1996) ['Comedy' 'Drama']
# 236 Jerry Maguire (1996) ['Drama' 'Romance']
# 237 Raising Arizona (1987) ['Comedy']
# 238 Sneakers (1992) ['Crime' 'Drama' 'Sci-Fi']
# 239 Beavis and Butt-head Do America (1996) ['Animation' 'Comedy']
# 240 Last of the Mohicans, The (1992) ['Action' 'Romance' 'War']
# 241 Kolya (1996) ['Comedy']
# 242 Jungle2Jungle (1997) ['Children’s' 'Comedy']
# 243 Smilla's Sense of Snow (1997) ['Action' 'Drama' 'Thriller']
# 244 Devil's Own, The (1997) ['Action' 'Drama' 'Thriller' 'War']
# 245 Chasing Amy (1997) ['Drama' 'Romance']
# 246 Turbo: A Power Rangers Movie (1997) ['Action' 'Adventure' 'Children’s']
# 247 Grosse Pointe Blank (1997) ['Comedy' 'Crime']
# 248 Austin Powers: International Man of Mystery (1997) ['Comedy']
# 249 Fifth Element, The (1997) ['Action' 'Sci-Fi']
# 250 Shall We Dance? (1996) ['Comedy']
# 251 Lost World: Jurassic Park, The (1997) ['Action' 'Adventure' 'Sci-Fi' 'Thriller']
# 252 Pillow Book, The (1995) ['Drama' 'Romance']
# 253 Batman & Robin (1997) ['Action' 'Adventure' 'Crime']
# 254 My Best Friend's Wedding (1997) ['Comedy' 'Romance']
# 255 When the Cats Away (Chacun cherche son chat) (1996) ['Comedy' 'Romance']
# 256 Men in Black (1997) ['Action' 'Adventure' 'Comedy' 'Sci-Fi']
# 257 Contact (1997) ['Drama' 'Sci-Fi']
# 258 George of the Jungle (1997) ['Children’s' 'Comedy']
# 259 Event Horizon (1997) ['Action' 'Mystery' 'Sci-Fi' 'Thriller']
# 260 Air Bud (1997) ['Children’s' 'Comedy']
# 261 In the Company of Men (1997) ['Drama']
# 262 Steel (1997) ['Action']
# 263 Mimic (1997) ['Sci-Fi' 'Thriller']
# 264 Hunt for Red October, The (1990) ['Action' 'Thriller']
# 265 Kull the Conqueror (1997) ['Action' 'Adventure']
# 266 unknown ['Unknown']
# 267 Chasing Amy (1997) ['Drama' 'Romance']
# 268 Full Monty, The (1997) ['Comedy']
# 269 Gattaca (1997) ['Drama' 'Sci-Fi' 'Thriller']
# 270 Starship Troopers (1997) ['Action' 'Adventure' 'Sci-Fi' 'War']
# 271 Good Will Hunting (1997) ['Drama']
# 272 Heat (1995) ['Action' 'Crime' 'Thriller']
# 273 Sabrina (1995) ['Comedy' 'Romance']
# 274 Sense and Sensibility (1995) ['Drama' 'Romance']
# 275 Leaving Las Vegas (1995) ['Drama' 'Romance']
# 276 Restoration (1995) ['Drama']
# 277 Bed of Roses (1996) ['Drama' 'Romance']
# 278 Once Upon a Time... When We Were Colored (1995) ['Drama']
# 279 Up Close and Personal (1996) ['Drama' 'Romance']
# 280 River Wild, The (1994) ['Action' 'Thriller']
# 281 Time to Kill, A (1996) ['Drama']
# 282 Emma (1996) ['Drama' 'Romance']
# 283 Tin Cup (1996) ['Comedy' 'Romance']
# 284 Secrets & Lies (1996) ['Drama']
# 285 English Patient, The (1996) ['Drama' 'Romance' 'War']
# 286 Marvin's Room (1996) ['Drama']
# 287 Scream (1996) ['Horror' 'Thriller']
# 288 Evita (1996) ['Drama' 'Musical']
# 289 Fierce Creatures (1997) ['Comedy']
# 290 Absolute Power (1997) ['Mystery' 'Thriller']
# 291 Rosewood (1997) ['Drama']
# 292 Donnie Brasco (1997) ['Crime' 'Drama']
# 293 Liar Liar (1997) ['Comedy']
# 294 Breakdown (1997) ['Action' 'Thriller']
# 295 Promesse, La (1996) ['Drama']
# 296 Ulee's Gold (1997) ['Drama']
# 297 Face/Off (1997) ['Action' 'Sci-Fi' 'Thriller']
# 298 Hoodlum (1997) ['Crime' 'Drama' 'Film-Noir']
# 299 Air Force One (1997) ['Action' 'Thriller']
# 300 In & Out (1997) ['Comedy']
# 301 L.A. Confidential (1997) ['Crime' 'Film-Noir' 'Mystery' 'Thriller']
# 302 Ulee's Gold (1997) ['Drama']
# 303 Fly Away Home (1996) ['Adventure' 'Children’s']
# 304 Ice Storm, The (1997) ['Drama']
# 305 Mrs. Brown (Her Majesty, Mrs. Brown) (1997) ['Drama' 'Romance']
# 306 Devil's Advocate, The (1997) ['Crime' 'Horror' 'Mystery' 'Thriller']
# 307 FairyTale: A True Story (1997) ['Children’s' 'Drama' 'Fantasy']
# 308 Deceiver (1997) ['Crime']
# 309 Rainmaker, The (1997) ['Drama']
# 310 Wings of the Dove, The (1997) ['Drama' 'Romance' 'Thriller']
# 311 Midnight in the Garden of Good and Evil (1997) ['Comedy' 'Crime' 'Drama' 'Mystery']
# 312 Titanic (1997) ['Action' 'Drama' 'Romance']
# 313 3 Ninjas: High Noon At Mega Mountain (1998) ['Action' 'Children’s']
# 314 Apt Pupil (1998) ['Drama' 'Thriller']
# 315 As Good As It Gets (1997) ['Comedy' 'Drama']
# 316 In the Name of the Father (1993) ['Drama']
# 317 Schindler's List (1993) ['Drama' 'War']
# 318 Everyone Says I Love You (1996) ['Comedy' 'Musical' 'Romance']
# 319 Paradise Lost: The Child Murders at Robin Hood Hills (1996) ['Documentary']
# 320 Mother (1996) ['Comedy']
# 321 Murder at 1600 (1997) ['Mystery' 'Thriller']
# 322 Dante's Peak (1997) ['Action' 'Thriller']
# 323 Lost Highway (1997) ['Mystery']
# 324 Crash (1996) ['Drama' 'Thriller']
# 325 G.I. Jane (1997) ['Action' 'Drama' 'War']
# 326 Cop Land (1997) ['Crime' 'Drama' 'Mystery']
# 327 Conspiracy Theory (1997) ['Action' 'Mystery' 'Romance' 'Thriller']
# 328 Desperate Measures (1998) ['Crime' 'Drama' 'Thriller']
# 329 187 (1997) ['Drama']
# 330 Edge, The (1997) ['Adventure' 'Thriller']
# 331 Kiss the Girls (1997) ['Crime' 'Drama' 'Thriller']
# 332 Game, The (1997) ['Mystery' 'Thriller']
# 333 U Turn (1997) ['Action' 'Crime' 'Mystery']
# 334 How to Be a Player (1997) ['Comedy']
# 335 Playing God (1997) ['Crime' 'Thriller']
# 336 House of Yes, The (1997) ['Comedy' 'Drama' 'Thriller']
# 337 Bean (1997) ['Comedy']
# 338 Mad City (1997) ['Action' 'Drama']
# 339 Boogie Nights (1997) ['Drama']
# 340 Critical Care (1997) ['Comedy']
# 341 Man Who Knew Too Little, The (1997) ['Comedy' 'Mystery']
# 342 Alien: Resurrection (1997) ['Action' 'Horror' 'Sci-Fi']
# 343 Apostle, The (1997) ['Drama']
# 344 Deconstructing Harry (1997) ['Comedy' 'Drama']
# 345 Jackie Brown (1997) ['Crime' 'Drama']
# 346 Wag the Dog (1997) ['Comedy' 'Drama']
# 347 Desperate Measures (1998) ['Crime' 'Drama' 'Thriller']
# 348 Hard Rain (1998) ['Action' 'Thriller']
# 349 Fallen (1998) ['Action' 'Mystery' 'Thriller']
# 350 Prophecy II, The (1998) ['Horror']
# 351 Spice World (1997) ['Comedy' 'Musical']
# 352 Deep Rising (1998) ['Action' 'Horror' 'Sci-Fi']
# 353 Wedding Singer, The (1998) ['Comedy' 'Romance']
# 354 Sphere (1998) ['Adventure' 'Sci-Fi' 'Thriller']
# 355 Client, The (1994) ['Drama' 'Mystery' 'Thriller']
# 356 One Flew Over the Cuckoo's Nest (1975) ['Drama']
# 357 Spawn (1997) ['Action' 'Adventure' 'Sci-Fi' 'Thriller']
# 732 Go Fish (1994) ['Drama' 'Romance']
# 733 Made in America (1993) ['Comedy']
# 734 Philadelphia (1993) ['Drama']
# 735 Shadowlands (1993) ['Drama' 'Romance']
# 736 Sirens (1994) ['Comedy' 'Drama']
# 737 Threesome (1994) ['Comedy' 'Romance']
# 738 Pretty Woman (1990) ['Comedy' 'Romance']
# 739 Jane Eyre (1996) ['Drama' 'Romance']
# 740 Last Supper, The (1995) ['Drama' 'Thriller']
# 741 Ransom (1996) ['Drama' 'Thriller']
# 742 Crow: City of Angels, The (1996) ['Action' 'Thriller']
# 743 Michael Collins (1996) ['Drama' 'War']
# 744 Ruling Class, The (1972) ['Comedy']
# 745 Real Genius (1985) ['Comedy']
# 746 Benny & Joon (1993) ['Comedy' 'Romance']
# 747 Saint, The (1997) ['Action' 'Romance' 'Thriller']
# 748 MatchMaker, The (1997) ['Comedy' 'Romance']
# 749 Amistad (1997) ['Drama']
# 750 Tomorrow Never Dies (1997) ['Action' 'Romance' 'Thriller']
# 751 Replacement Killers, The (1998) ['Action' 'Thriller']
# 752 Burnt By the Sun (1994) ['Drama']
# 753 Red Corner (1997) ['Crime' 'Thriller']
# 754 Jumanji (1995) ['Action' 'Adventure' 'Children’s' 'Fantasy' 'Sci-Fi']
# 755 Father of the Bride Part II (1995) ['Comedy']
# 756 Across the Sea of Time (1995) ['Documentary']
# 757 Lawnmower Man 2: Beyond Cyberspace (1996) ['Sci-Fi' 'Thriller']
# 758 Fair Game (1995) ['Action']
# 759 Screamers (1995) ['Sci-Fi']
# 760 Nick of Time (1995) ['Action' 'Thriller']
# 761 Beautiful Girls (1996) ['Drama']
# 762 Happy Gilmore (1996) ['Comedy']
# 763 If Lucy Fell (1996) ['Comedy' 'Romance']
# 764 Boomerang (1992) ['Comedy' 'Romance']
# 765 Man of the Year (1995) ['Documentary']
# 766 Addiction, The (1995) ['Horror']
# 767 Casper (1995) ['Adventure' 'Children’s']
# 768 Congo (1995) ['Action' 'Adventure' 'Mystery' 'Sci-Fi']
# 769 Devil in a Blue Dress (1995) ['Crime' 'Film-Noir' 'Mystery' 'Thriller']
# 770 Johnny Mnemonic (1995) ['Action' 'Sci-Fi' 'Thriller']
# 771 Kids (1995) ['Drama']
# 772 Mute Witness (1994) ['Thriller']
# 773 Prophecy, The (1995) ['Horror']
# 774 Something to Talk About (1995) ['Comedy' 'Drama' 'Romance']
# 775 Three Wishes (1995) ['Drama']
# 776 Castle Freak (1995) ['Horror']
# 777 Don Juan DeMarco (1995) ['Comedy' 'Drama' 'Romance']
# 778 Drop Zone (1994) ['Action']
# 779 Dumb & Dumber (1994) ['Comedy']
# 780 French Kiss (1995) ['Comedy' 'Romance']
# 781 Little Odessa (1994) ['Drama']
# 782 Milk Money (1994) ['Comedy' 'Romance']
# 783 Beyond Bedlam (1993) ['Drama' 'Horror']
# 784 Only You (1994) ['Comedy' 'Romance']
# 785 Perez Family, The (1995) ['Comedy' 'Romance']
# 786 Roommates (1995) ['Comedy' 'Drama']
# 787 Relative Fear (1994) ['Horror' 'Thriller']
# 788 Swimming with Sharks (1995) ['Comedy' 'Drama']
# 789 Tommy Boy (1995) ['Comedy']
# 790 Baby-Sitters Club, The (1995) ['Children’s']
# 791 Bullets Over Broadway (1994) ['Comedy']
# 792 Crooklyn (1994) ['Comedy']
# 793 It Could Happen to You (1994) ['Drama' 'Romance']
# 794 Richie Rich (1994) ['Children’s' 'Comedy']
# 795 Speechless (1994) ['Comedy' 'Romance']
# 796 Timecop (1994) ['Action' 'Sci-Fi']
# 797 Bad Company (1995) ['Action']
# 798 Boys Life (1995) ['Drama']
# 799 In the Mouth of Madness (1995) ['Horror' 'Thriller']
# 800 Air Up There, The (1994) ['Comedy']
# 801 Hard Target (1993) ['Action' 'Adventure' 'Crime' 'Thriller']
# 802 Heaven & Earth (1993) ['Action' 'Drama' 'War']
# 803 Jimmy Hollywood (1994) ['Comedy']
# 804 Manhattan Murder Mystery (1993) ['Comedy' 'Mystery']
# 805 Menace II Society (1993) ['Action' 'Crime' 'Drama']
# 806 Poetic Justice (1993) ['Drama']
# 807 Program, The (1993) ['Action' 'Drama']
# 808 Rising Sun (1993) ['Action' 'Drama' 'Mystery']
# 809 Shadow, The (1994) ['Action']
# 810 Thirty-Two Short Films About Glenn Gould (1993) ['Documentary']
# 811 Andre (1994) ['Adventure' 'Children’s']
# 812 Celluloid Closet, The (1995) ['Documentary']
# 813 Great Day in Harlem, A (1994) ['Documentary']
# 814 One Fine Day (1996) ['Drama' 'Romance']
# 815 Candyman: Farewell to the Flesh (1995) ['Horror']
# 816 Frisk (1995) ['Drama']
# 817 Girl 6 (1996) ['Comedy']
# 818 Eddie (1996) ['Comedy']
# 819 Space Jam (1996) ['Adventure' 'Animation' 'Children’s' 'Comedy' 'Fantasy']
# 820 Mrs. Winterbourne (1996) ['Comedy' 'Romance']
# 821 Faces (1968) ['Drama']
# 822 Mulholland Falls (1996) ['Crime' 'Film-Noir' 'Thriller']
# 823 Great White Hype, The (1996) ['Comedy']
# 824 Arrival, The (1996) ['Action' 'Sci-Fi' 'Thriller']
# 825 Phantom, The (1996) ['Adventure']
# 826 Daylight (1996) ['Action' 'Adventure' 'Thriller']
# 827 Alaska (1996) ['Adventure' 'Children’s']
# 828 Fled (1996) ['Action' 'Adventure']
# 829 Power 98 (1995) ['Action' 'Mystery' 'Thriller']
# 830 Escape from L.A. (1996) ['Action' 'Adventure' 'Sci-Fi' 'Thriller']
# 831 Bogus (1996) ['Children’s' 'Drama' 'Fantasy']
# 832 Bulletproof (1996) ['Action']
# 833 Halloween: The Curse of Michael Myers (1995) ['Horror' 'Thriller']
# 834 Gay Divorcee, The (1934) ['Comedy' 'Musical' 'Romance']
# 835 Ninotchka (1939) ['Comedy' 'Romance']
# 836 Meet John Doe (1941) ['Drama']
# 837 In the Line of Duty 2 (1987) ['Action']
# 838 Loch Ness (1995) ['Horror' 'Thriller']
# 839 Last Man Standing (1996) ['Action' 'Drama' 'Western']
# 840 Glimmer Man, The (1996) ['Action' 'Thriller']
# 841 Pollyanna (1960) ['Children’s' 'Comedy' 'Drama']
